# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (1.27.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: validators<1,>=0.2 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: altair<6,>=4.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (5.1.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pyarrow>=6.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (13.0.0)
# Requirement already satisfied: pillow<10,>=7.1.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: requests<3,>=2.18 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (3.1.36)
# Requirement already satisfied: click<9,>=7.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (13.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (6.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (22.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from streamlit) (4.24.3)
# Requirement already satisfied: jinja2 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (1.26.14)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/peeeeeh/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import numpy as np
import pandas as pd


st.title("Streamlit 超入門")

st.write("DataFrame")

df = pd.DataFrame({
      "1列目" : [1, 2, 3, 4],
      "2列目" : [10, 20, 30, 40],
})
df
# Out:
#    1列目  2列目
# 0    1   10
# 1    2   20
# 2    3   30
# 3    4   40

# %%
import streamlit as st
import numpy as np
import pandas as pd

st.title("Streamlit 超入門")

st.write("DataFrame")

df = pd.DataFrame(
    np.random.rand(20, 3),
    columns=['a', 'b', 'c']
)
df
# Out:
#            a         b         c
# 0   0.368524  0.710942  0.108170
# 1   0.242332  0.105578  0.390625
# 2   0.780685  0.910025  0.996245
# 3   0.235306  0.815508  0.989024
# 4   0.844931  0.972562  0.041575
# 5   0.082411  0.911368  0.027361
# 6   0.825992  0.441267  0.772227
# 7   0.237040  0.791674  0.686236
# 8   0.084342  0.301560  0.908385
# 9   0.927153  0.875057  0.471843
# 10  0.859409  0.371981  0.459060
# 11  0.333416  0.260039  0.790048
# 12  0.342400  0.304507  0.605762
# 13  0.347475  0.943811  0.537474
# 14  0.971974  0.767757  0.779576
# 15  0.510509  0.113168  0.236678
# 16  0.245567  0.131806  0.473262
# 17  0.439256  0.746144  0.146349
# 18  0.811105  0.657012  0.606620
# 19  0.197254  0.602094  0.384821
